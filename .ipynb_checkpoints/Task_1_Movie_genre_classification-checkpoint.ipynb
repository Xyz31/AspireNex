# %% [markdown]
# <a href="https://colab.research.google.com/github/Xyz31/AspireNex/blob/main/Task_1_Movie_genre_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **step** 1 : Load Data Sets

# %% [markdown]
# train_data: Contains training data with columns 'Title', 'Genre', and 'Description'.

# %%
import pandas as pd

# Load training dataset from a text file
train_file_path = "/content/drive/MyDrive/Genre Classification Dataset/train_data.txt"
train_data = pd.read_csv(train_file_path, sep=':::', names=['Title', 'Genre', 'Description'], engine='python')
train_data
# Out:
#                                               Title          Genre  \
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              Description
# 1       Listening in to a conversation between his do...
# 2       A brother and sister with a past incestuous r...
# 3       As the bus empties the students for their fie...
# 4       To help their unemployed father make ends mee...
# 5       The film's title refers not only to the un-re...
# ...                                                  ...
# 54210   This short-lived NBC live sitcom centered on ...
# 54211   The NEXT Generation of EXPLOITATION. The sist...
# 54212   Ze bestaan echt, is a stand-up comedy about g...
# 54213   Walter and Vivian live in the country and hav...
# 54214   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %% [markdown]
# test_data: Contains test data with columns 'Id', 'Title', and 'Description'.

# %%
# Load test dataset from a text file
test_file_path = "/content/drive/MyDrive/Genre Classification Dataset/test_data.txt"
test_data = pd.read_csv(test_file_path, sep=':::', names=['Id', 'Title', 'Description'], engine='python')
test_data
# Out:
#           Id                             Title  \
# 0          1             Edgar's Lunch (1998)
# 1          2         La guerra de papá (1977)
# 2          3      Off the Beaten Track (2010)
# 3          4           Meu Amigo Hindu (2015)
# 4          5                Er nu zhai (1955)
# ...      ...                               ...
# 54195  54196   "Tales of Light & Dark" (2013)
# 54196  54197      Der letzte Mohikaner (1965)
# 54197  54198              Oliver Twink (2007)
# 54198  54199                Slipstream (1973)
# 54199  54200        Curitiba Zero Grau (2010)
#
#                                              Description
# 0       L.R. Brane loves his life - his car, his apar...
# 1       Spain, March 1964: Quico is a very naughty ch...
# 2       One year in the life of Albin and his family ...
# 3       His father has died, he hasn't spoken with hi...
# 4       Before he was known internationally as a mart...
# ...                                                  ...
# 54195   Covering multiple genres, Tales of Light & Da...
# 54196   As Alice and Cora Munro attempt to find their...
# 54197   A movie 169 years in the making. Oliver Twist...
# 54198   Popular, but mysterious rock D.J Mike Mallard...
# 54199   Curitiba is a city in movement, with rhythms ...
#
# [54200 rows x 3 columns]

# %% [markdown]
# test_data_solution: Contains test data solution with columns 'Id', 'Title','Genre' and 'Description'.
#
#
# ** The data is separated by the ':::' delimiter and the engine is set to 'python' for parsing.**

# %%
# Load test solution dataset from a text file
test_file_path = "/content/drive/MyDrive/Genre Classification Dataset/test_data_solution.txt"
test_data_solution = pd.read_csv(test_file_path, sep=':::', names=['Id', 'Title', 'Description'], engine='python')
test_data_solution
# Out:
#                                      Id          Title  \
# 1                 Edgar's Lunch (1998)       thriller
# 2             La guerra de papá (1977)         comedy
# 3          Off the Beaten Track (2010)    documentary
# 4               Meu Amigo Hindu (2015)          drama
# 5                    Er nu zhai (1955)          drama
# ...                                 ...            ...
# 54196   "Tales of Light & Dark" (2013)         horror
# 54197      Der letzte Mohikaner (1965)        western
# 54198              Oliver Twink (2007)          adult
# 54199                Slipstream (1973)          drama
# 54200        Curitiba Zero Grau (2010)          drama
#
#                                              Description
# 1       L.R. Brane loves his life - his car, his apar...
# 2       Spain, March 1964: Quico is a very naughty ch...
# 3       One year in the life of Albin and his family ...
# 4       His father has died, he hasn't spoken with hi...
# 5       Before he was known internationally as a mart...
# ...                                                  ...
# 54196   Covering multiple genres, Tales of Light & Da...
# 54197   As Alice and Cora Munro attempt to find their...
# 54198   A movie 169 years in the making. Oliver Twist...
# 54199   Popular, but mysterious rock D.J Mike Mallard...
# 54200   Curitiba is a city in movement, with rhythms ...
#
# [54200 rows x 3 columns]

# %% [markdown]
# ### Step - 2 : Visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot genre distribution
plt.figure(figsize=(12, 6))
sns.countplot(y='Genre', data=train_data, order=train_data['Genre'].value_counts().index)
plt.title('Genre Distribution')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = train_data
# Create a sample DataFrame
df = pd.DataFrame({
    'v1': ['a', 'b', 'a', 'c', 'b', 'a'],
    'v2': ['short', 'long', 'medium', 'long', 'short', 'medium']
})

df['length'] = df['v2'].apply(len)


plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='length', hue='v1', kde=True, bins=50)


plt.title('Distribution of Message Lengths')
plt.xlabel('Message Length')
plt.ylabel('Count')
plt.show()

# %%
from wordcloud import WordCloud

# Combine all descriptions into a single string
all_descriptions = ' '.join(train_data['Description'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_descriptions)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Movie Descriptions')
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import plotly.express as px

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(train_data['Description'])
y_train = train_data['Genre']
X_test_tfidf = tfidf_vectorizer.transform(test_data['Description'])
y_test = test_data_solution['Genre']

# %%
# Perform PCA
pca = PCA(n_components=3)
X_pca_3d = pca.fit_transform(X_train_tfidf.toarray())

# Create a DataFrame for Plotly
df_3d = pd.DataFrame(
    data=X_pca_3d,
    columns=['PC1', 'PC2', 'PC3']
)
df_3d['Class'] = y_train

# Create an interactive 3D scatter plot
fig = px.scatter_3d(
    df_3d,
    x='PC1',
    y='PC2',
    z='PC3',
    color='Class',
    title='3D Scatter Plot of PCA Features Colored by Class'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9a78192-0757-4b16-ae5c-1de6bb2990b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9a78192-0757-4b16-ae5c-1de6bb2990b2")) {                    Plotly.newPlot(                        "b9a78192-0757-4b16-ae5c-1de6bb2990b2",                        [{"hovertemplate":"Class= drama \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" drama ","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":" drama ","scene":"scene","showlegend":true,"x":[0.08419789791316676,-0.17659010238060913,-0.09915389622909111,-0.03785098428538696,0.0879045751391831,0.016225159460314158,-0.05841226097290227,0.11302371748000188,-0.006851423417349334,-0.0037482724712151402,-0.08432636949481853,-0.10481615725521934,-0.03634647005923328,0.016401015487752073,0.01566951705379721,-0.14319738459136228,0.03464598952935539,0.051748480211596046,0.003082665912766206,-0.12884030474983524,-0.0700613206747087,-0.045512247359494454,0.07741990980199412,0.16574796697270133,-0.1379359573369267,-0.025684173638115825,-0.11978406755052849,0.21317257169709045,-0.07313414313427706,0.11811898443392942,-0.041528482469766835,-0.048121299481702504,-0.0717771652432502,0.0014816494923923266,0.18373088076373814,-0.1289236082138287,-0.16161263383813115,0.07979789539600769,-0.023867476246832532,0.03785995403858569,0.003111166152737224,0.048274140246229426,-0.07861543578390298,-0.03999732718619527,-0.07427860639527534,-0.07627597549939516,0.11955701323359677,0.027017513562551665,0.00884964504331704,0.1380119151149852,-0.055063265550218274,0.08031787868891918,-0.06741601769057946,0.180321208937626,-0.1193870044062324,0.02000880456866305,-0.12022639392803845,-0.24483515134726722,-0.08266455363423408,0.02286033047320439,-0.0051119310518532475,-0.07703620933194869,-0.13476817441751435,0.11657206398169077,0.10605527294794447,-0.018253636084016377,-0.13063688075734484,0.006519134147307363,0.04237996686802966,-0.11138166046749653,-0.11251452960515128,-0.07370338782919882,-0.06194584761536408,-0.13380000750056256,0.0005961072226089205,0.28690365290198105,0.07552114529807784,-0.13150498278093453,-0.06833702489438698,-0.0085351804563567,-0.020047627897317684,-0.012455388774795479,-0.05674854594132027,-0.041608120797914525,-0.05740835813726084,0.1395330546575988,-0.05913477119973129,0.04712638647492564,-0.022882814388811755,-0.06043796835109072,0.07426409053088998,0.0752748215304876,-0.0640640865123911,-0.19088515255170738,-0.010731366264089855,-0.08191074282237876,0.03363438972035729,0.09758489890875473,-0.06883675871097358,0.03986429985449064,-0.03529913356305224,-0.14652159026942094,-0.14987818844742848,-0.132290743751887,-0.021376899197466503,0.09954381971845505,-0.023845027352409162,-0.046613674749405185,0.060797759719455995,0.016886026408580133,0.14470567045278598,0.015350580555597414,0.10806904671113353,0.13559484592303175,0.2305616218878532,-0.0355294414213264,0.13146684400582562,0.13019240086884418,0.059895332758739206,0.03823506170374749,0.10199950428739119,-0.1068201543488472,0.25299352574239997,-0.13168856908112694,0.031073065280761186,-0.16068579505376196,0.1712522496922851,-0.09761544891422709,-0.12972363156816755,0.031110675000946806,-0.014874036703792982,-0.12529945762076083,0.3540290018540266,-0.044873340214977527,-0.002648746994635637,-0.046802390184026196,0.10534744487938838,0.045351527974652577,0.026180295553931587,0.15927197656859032,-0.056878367124963705,0.09304191940941411,0.15731655370358785,0.040028449456330946,0.012956091403043182,-0.03493847281038742,0.026218493530199092,0.004316800743738698,0.0344466858721193,0.024456372699031875,0.12123818683195002,0.02496327109613523,0.046 ...

# %% [markdown]
# ### Step - 3 Train and Evaluate Model

# %% [markdown]
# #### Model 1

# %%
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_tfidf, y_train)
y_test_pred_nb = nb_classifier.predict(X_test_tfidf)

print("Naive Bayes - Accuracy on test set:", accuracy_score(y_test, y_test_pred_nb))
print("Naive Bayes - Classification Report on test set:\n", classification_report(y_test, y_test_pred_nb))
# Out:
# Naive Bayes - Accuracy on test set: 0.51380073800738
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Naive Bayes - Classification Report on test set:
#                 precision    recall  f1-score   support
#
#       action        0.61      0.08      0.13      1314
#        adult        0.53      0.04      0.07       590
#    adventure        0.78      0.04      0.08       775
#    animation        0.00      0.00      0.00       498
#    biography        0.00      0.00      0.00       264
#       comedy        0.52      0.40      0.45      7446
#        crime        0.00      0.00      0.00       505
#  documentary        0.56      0.88      0.69     13096
#        drama        0.45      0.83      0.58     13612
#       family        1.00      0.00      0.00       783
#      fantasy        0.00      0.00      0.00       322
#    game-show        0.96      0.12      0.22       193
#      history        0.00      0.00      0.00       243
#       horror        0.73      0.28      0.41      2204
#        music        0.76      0.10      0.18       731
#      musical        0.00      0.00      0.00       276
#      mystery        0.00      0.00      0.00       318
#         news        0.00      0.00      0.00       181
#   reality-tv        0.41      0.01      0.02       883
#      romance        0.00      0.00      0.00       672
#       sci-fi        0.70      0.02      0.05       646
#        short        0.61      0.10      0.16      5072
#        sport        0.80      0.09      0.16       431
#    talk-show        0.00      0.00      0.00       391
#     thriller        0.44      0.01      0.02      1590
#          war        0.00      0.00      0.00       132
#      western        0.96      0.53      0.69      1032
#
#      accuracy                           0.51     54200
#     macro avg       0.40      0.13      0.15     54200
#  weighted avg       0.52      0.51      0.43     54200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
test_data_solution['Predicted Genre'] = y_test_pred_nb
# test_data_solution.to_csv('predicted_genres.csv', index=False)
print(test_data_solution)
# Out:
#           Id                             Title          Genre  \
# 0          1             Edgar's Lunch (1998)       thriller
# 1          2         La guerra de papá (1977)         comedy
# 2          3      Off the Beaten Track (2010)    documentary
# 3          4           Meu Amigo Hindu (2015)          drama
# 4          5                Er nu zhai (1955)          drama
# ...      ...                               ...            ...
# 54195  54196   "Tales of Light & Dark" (2013)         horror
# 54196  54197      Der letzte Mohikaner (1965)        western
# 54197  54198              Oliver Twink (2007)          adult
# 54198  54199                Slipstream (1973)          drama
# 54199  54200        Curitiba Zero Grau (2010)          drama
#
#                                              Description Predicted Genre
# 0       L.R. Brane loves his life - his car, his apar...          drama
# 1       Spain, March 1964: Quico is a very naughty ch...          drama
# 2       One year in the life of Albin and his family ...    documentary
# 3       His father has died, he hasn't spoken with hi...          drama
# 4       Before he was known internationally as a mart...          drama
# ...                                                  ...             ...
# 54195   Covering multiple genres, Tales of Light & Da...          drama
# 54196   As Alice and Cora Munro attempt to find their...          drama
# 54197   A movie 169 years in the making. Oliver Twist...         comedy
# 54198   Popular, but mysterious rock D.J Mike Mallard...          drama
# 54199   Curitiba is a city in movement, with rhythms ...    documentary
#
# [54200 rows x 5 columns]

# %% [markdown]
# #### Model 2

# %%
logreg_classifier = LogisticRegression(max_iter=1000)
logreg_classifier.fit(X_train_tfidf, y_train)
y_test_pred_logreg = logreg_classifier.predict(X_test_tfidf)

print("Logistic Regression - Accuracy on test set:", accuracy_score(y_test, y_test_pred_logreg))
print("Logistic Regression - Classification Report on test set:\n", classification_report(y_test, y_test_pred_logreg))
# Out:
# Logistic Regression - Accuracy on test set: 0.5888745387453874
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Logistic Regression - Classification Report on test set:
#                 precision    recall  f1-score   support
#
#       action        0.47      0.29      0.36      1314
#        adult        0.63      0.25      0.35       590
#    adventure        0.59      0.16      0.25       775
#    animation        0.50      0.05      0.09       498
#    biography        0.00      0.00      0.00       264
#       comedy        0.53      0.59      0.56      7446
#        crime        0.36      0.03      0.06       505
#  documentary        0.68      0.86      0.76     13096
#        drama        0.55      0.77      0.64     13612
#       family        0.49      0.09      0.15       783
#      fantasy        0.59      0.03      0.06       322
#    game-show        0.89      0.50      0.64       193
#      history        0.00      0.00      0.00       243
#       horror        0.64      0.56      0.60      2204
#        music        0.65      0.47      0.55       731
#      musical        0.31      0.02      0.03       276
#      mystery        0.40      0.01      0.01       318
#         news        0.73      0.06      0.11       181
#   reality-tv        0.49      0.22      0.30       883
#      romance        0.42      0.03      0.06       672
#       sci-fi        0.57      0.26      0.35       646
#        short        0.47      0.34      0.40      5072
#        sport        0.68      0.28      0.39       431
#    talk-show        0.57      0.20      0.29       391
#     thriller        0.40      0.13      0.20      1590
#          war        1.00      0.02      0.04       132
#      western        0.91      0.73      0.81      1032
#
#      accuracy                           0.59     54200
#     macro avg       0.54      0.26      0.30     54200
#  weighted avg       0.57      0.59      0.55     54200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# #### Model 3

# %%
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

svm_classifier = LinearSVC(C=0.1, max_iter=1000, dual=False)

# Fit the model
svm_classifier.fit(X_train_tfidf, y_train)

# Predict
y_test_pred_svm = svm_classifier.predict(X_test_tfidf)

print("SVM - Accuracy on test set:", accuracy_score(y_test, y_test_pred_svm))
print("SVM - Classification Report on test set:\n", classification_report(y_test, y_test_pred_svm))
# Out:
# SVM - Accuracy on test set: 0.5868634686346863
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# SVM - Classification Report on test set:
#                 precision    recall  f1-score   support
#
#       action        0.47      0.24      0.32      1314
#        adult        0.62      0.26      0.37       590
#    adventure        0.61      0.14      0.23       775
#    animation        0.53      0.05      0.10       498
#    biography        0.00      0.00      0.00       264
#       comedy        0.54      0.57      0.55      7446
#        crime        0.45      0.02      0.04       505
#  documentary        0.66      0.88      0.75     13096
#        drama        0.54      0.78      0.64     13612
#       family        0.49      0.06      0.11       783
#      fantasy        0.69      0.03      0.05       322
#    game-show        0.80      0.59      0.68       193
#      history        0.00      0.00      0.00       243
#       horror        0.60      0.60      0.60      2204
#        music        0.62      0.46      0.53       731
#      musical        0.25      0.01      0.02       276
#      mystery        0.50      0.01      0.01       318
#         news        0.79      0.06      0.11       181
#   reality-tv        0.56      0.18      0.27       883
#      romance        0.75      0.00      0.01       672
#       sci-fi        0.53      0.25      0.34       646
#        short        0.51      0.28      0.36      5072
#        sport        0.67      0.27      0.38       431
#    talk-show        0.63      0.18      0.28       391
#     thriller        0.40      0.09      0.14      1590
#          war        1.00      0.02      0.04       132
#      western        0.85      0.80      0.83      1032
#
#      accuracy                           0.59     54200
#     macro avg       0.56      0.25      0.29     54200
#  weighted avg       0.57      0.59      0.54     54200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# #### Model 4

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train Random Forest model
rf_classifier = RandomForestClassifier(n_estimators=70, max_depth=100,random_state=42)
rf_classifier.fit(X_train_tfidf, y_train)

# Predict on test data
y_test_pred_rf = rf_classifier.predict(X_test_tfidf)

# Evaluate the model
print("Random Forest - Accuracy on test set:", accuracy_score(y_test, y_test_pred_rf))
print("Random Forest - Classification Report on test set:\n", classification_report(y_test, y_test_pred_rf))
# Out:
# Random Forest - Accuracy on test set: 0.4712177121771218
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Random Forest - Classification Report on test set:
#                 precision    recall  f1-score   support
#
#       action        1.00      0.00      0.01      1314
#        adult        0.52      0.03      0.05       590
#    adventure        0.70      0.05      0.09       775
#    animation        0.09      0.00      0.00       498
#    biography        0.00      0.00      0.00       264
#       comedy        0.49      0.24      0.33      7446
#        crime        1.00      0.00      0.01       505
#  documentary        0.53      0.88      0.66     13096
#        drama        0.41      0.82      0.54     13612
#       family        0.92      0.01      0.03       783
#      fantasy        0.00      0.00      0.00       322
#    game-show        0.93      0.34      0.49       193
#      history        0.00      0.00      0.00       243
#       horror        0.68      0.08      0.14      2204
#        music        0.79      0.11      0.19       731
#      musical        1.00      0.02      0.04       276
#      mystery        1.00      0.00      0.01       318
#         news        0.00      0.00      0.00       181
#   reality-tv        0.43      0.01      0.01       883
#      romance        0.67      0.00      0.01       672
#       sci-fi        0.50      0.00      0.01       646
#        short        0.64      0.05      0.10      5072
#        sport        0.83      0.10      0.19       431
#    talk-show        0.64      0.02      0.04       391
#     thriller        0.50      0.00      0.01      1590
#          war        1.00      0.02      0.04       132
#      western        0.93      0.36      0.52      1032
#
#      accuracy                           0.47     54200
#     macro avg       0.60      0.12      0.13     54200
#  weighted avg       0.54      0.47      0.38     54200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# #### Model 5

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

# Encode the genre labels
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train)
y_test_encoded = encoder.transform(y_test)

# Convert labels to one-hot encoding
y_train_one_hot = to_categorical(y_train_encoded)
y_test_one_hot = to_categorical(y_test_encoded)

# Build the neural network model
nn_model = Sequential()
nn_model.add(Dense(128, input_dim=5000, activation='relu'))  # number of neurons
nn_model.add(Dropout(0.5))
nn_model.add(Dense(64, activation='relu'))  # number of neurons
nn_model.add(Dropout(0.5))
nn_model.add(Dense(len(np.unique(y_train_encoded)), activation='softmax'))

# Compile the model
nn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
nn_model.fit(X_train_tfidf.toarray(), y_train_one_hot, epochs=20, batch_size=64, validation_split=0.2, verbose=2)

# Predict on test data
y_test_pred_nn = nn_model.predict(X_test_tfidf.toarray())
y_test_pred_nn_labels = encoder.inverse_transform(np.argmax(y_test_pred_nn, axis=1))

# Evaluate
print("Neural Network - Accuracy on test set:", accuracy_score(y_test, y_test_pred_nn_labels))
print("Neural Network - Classification Report on test set:\n", classification_report(y_test, y_test_pred_nn_labels))
# Out:
# Epoch 1/20
# 678/678 - 5s - loss: 2.0440 - accuracy: 0.4332 - val_loss: 1.6618 - val_accuracy: 0.5395 - 5s/epoch - 8ms/step
# Epoch 2/20
# 678/678 - 3s - loss: 1.6231 - accuracy: 0.5472 - val_loss: 1.5129 - val_accuracy: 0.5697 - 3s/epoch - 4ms/step
# Epoch 3/20
# 678/678 - 3s - loss: 1.4666 - accuracy: 0.5866 - val_loss: 1.4739 - val_accuracy: 0.5758 - 3s/epoch - 4ms/step
# Epoch 4/20
# 678/678 - 2s - loss: 1.3619 - accuracy: 0.6124 - val_loss: 1.4617 - val_accuracy: 0.5783 - 2s/epoch - 4ms/step
# Epoch 5/20
# 678/678 - 2s - loss: 1.2662 - accuracy: 0.6354 - val_loss: 1.4618 - val_accuracy: 0.5830 - 2s/epoch - 3ms/step
# Epoch 6/20
# 678/678 - 3s - loss: 1.1858 - accuracy: 0.6560 - val_loss: 1.4899 - val_accuracy: 0.5814 - 3s/epoch - 4ms/step
# Epoch 7/20
# 678/678 - 3s - loss: 1.1072 - accuracy: 0.6757 - val_loss: 1.5100 - val_accuracy: 0.5791 - 3s/epoch - 4ms/step
# Epoch 8/20
# 678/678 - 3s - loss: 1.0321 - accuracy: 0.6952 - val_loss: 1.5302 - val_accuracy: 0.5747 - 3s/epoch - 4ms/step
# Epoch 9/20
# 678/678 - 2s - loss: 0.9636 - accuracy: 0.7146 - val_loss: 1.5887 - val_accuracy: 0.5727 - 2s/epoch - 3ms/step
# Epoch 10/20
# 678/678 - 3s - loss: 0.8988 - accuracy: 0.7303 - val_loss: 1.6133 - val_accuracy: 0.5747 - 3s/epoch - 4ms/step
# Epoch 11/20
# 678/678 - 2s - loss: 0.8411 - accuracy: 0.7492 - val_loss: 1.6913 - val_accuracy: 0.5756 - 2s/epoch - 3ms/step
# Epoch 12/20
# 678/678 - 3s - loss: 0.7845 - accuracy: 0.7651 - val_loss: 1.7521 - val_accuracy: 0.5722 - 3s/epoch - 4ms/step
# Epoch 13/20
# 678/678 - 3s - loss: 0.7383 - accuracy: 0.7726 - val_loss: 1.8306 - val_accuracy: 0.5689 - 3s/epoch - 5ms/step
# Epoch 14/20
# 678/678 - 2s - loss: 0.6912 - accuracy: 0.7880 - val_loss: 1.8889 - val_accuracy: 0.5702 - 2s/epoch - 3ms/step
# Epoch 15/20
# 678/678 - 2s - loss: 0.6516 - accuracy: 0.7980 - val_loss: 1.9587 - val_accuracy: 0.5699 - 2s/epoch - 3ms/step
# Epoch 16/20
# 678/678 - 2s - loss: 0.6170 - accuracy: 0.8085 - val_loss: 1.9968 - val_accuracy: 0.5657 - 2s/epoch - 3ms/step
# Epoch 17/20
# 678/678 - 3s - loss: 0.5796 - accuracy: 0.8178 - val_loss: 2.1291 - val_accuracy: 0.5625 - 3s/epoch - 4ms/step
# Epoch 18/20
# 678/678 - 3s - loss: 0.5552 - accuracy: 0.8241 - val_loss: 2.1754 - val_accuracy: 0.5651 - 3s/epoch - 5ms/step
# Epoch 19/20
# 678/678 - 2s - loss: 0.5328 - accuracy: 0.8312 - val_loss: 2.2440 - val_accuracy: 0.5662 - 2s/epoch - 3ms/step
# Epoch 20/20
# 678/678 - 2s - loss: 0.5109 - accuracy: 0.8385 - val_loss: 2.3207 - val_accuracy: 0.5622 - 2s/epoch - 3ms/step
# 1694/1694 [==============================] - 3s 2ms/step
# Neural Network - Accuracy on test set: 0.5570295202952029
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Neural Network - Classification Report on test set:
#                 precision    recall  f1-score   support
#
#       action        0.37      0.29      0.33      1314
#        adult        0.50      0.27      0.35       590
#    adventure        0.27      0.20      0.23       775
#    animation        0.22      0.13      0.16       498
#    biography        0.00      0.00      0.00       264
#       comedy        0.49      0.58      0.53      7446
#        crime        0.17      0.04      0.07       505
#  documentary        0.70      0.80      0.75     13096
#        drama        0.57      0.67      0.62     13612
#       family        0.23      0.13      0.17       783
#      fantasy        0.08      0.02      0.03       322
#    game-show        0.68      0.54      0.61       193
#      history        0.10      0.00      0.01       243
#       horror        0.60      0.55      0.57      2204
#        music        0.54      0.51      0.52       731
#      musical        0.29      0.07      0.11       276
#      mystery        0.04      0.00      0.01       318
#         news        0.33      0.01      0.02       181
#   reality-tv        0.36      0.28      0.32       883
#      romance        0.24      0.05      0.08       672
#       sci-fi        0.39      0.31      0.35       646
#        short        0.41      0.34      0.37      5072
#        sport        0.53      0.38      0.44       431
#    talk-show        0.34      0.28      0.31       391
#     thriller        0.26      0.22      0.24      1590
#          war        0.31      0.04      0.07       132
#      western        0.86      0.78      0.82      1032
#
#      accuracy                           0.56     54200
#     macro avg       0.37      0.28      0.30     54200
#  weighted avg       0.53      0.56      0.53     54200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
